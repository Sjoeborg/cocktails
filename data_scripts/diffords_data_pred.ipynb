# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('./difford_1_5000.csv')

# %%
pd.set_option('max_rows', 100)
pd.DataFrame([ingredient_dict]).transpose().sort_values(0).tail(100)
alcohol = ['vodka', 
           'gin',
           'whiskey',
           'rum',
           'brandy liqueur',
           'Gentian liqueur',
           'soda water', 
           'Ginger liqueur',
           'amaretto', 
           'Calvados', 
           'bitters',
           'Chartreuse liqueur',
           'Coffee Liqueur',
           'bitter liqueur',
           'elderflower liqueur',
           'Maraschino liqueur',
           'absinthe',
           'tequila',
           'Orange Bitters',
           'vermouth',
           'Cognac',
           'Aromatic Bitters',
           'Hazelnut liqueur',
           'Vanilia vodka',
           'Chocolate bitters',
           'sherry',
           'sparkling wine',
           'Sauvignon blanc wine',
           'wine',
           'southern liqueur',
           'Apple Schnapps liqueur',
           'Coconut rum liqueur',
           'Limoncello',
           'peach schnapps',
           'Green melon liqueur',
           'aperitivo',
           'Drambuie liqueur',
           'port',
           'Chocolate bitters',
           'mezcal',
           'Noir de Bourgogne',
           'Banane du Brésil liqueur',
           'Falernum liqueur',
           'Irish cream liqueur',
           'Chartreuse liqueur',
           'Champagne',
           'Straight rye whiskey',
           'Gentian liqueur',
           'Framboise de Ronce'
           'Chartreuse',
           'cognac orange liqueur',
           'Dry vermouth',
           'sweet vermouth'
]

# %%
def extract_words(ingredient_list):
    cleaned_list = []
    for i,ingredient in enumerate(eval(ingredient_list)):
        ingredient = "".join(re.split("\(|\)|\[|\]", ingredient)[::2])
        clean_ingredient = ' '.join([word for word in re.findall("[a-zA-Z'é]+",ingredient) if word not in words_to_remove])

        cleaned_list.append(clean_ingredient)
    cleaned_string = '|'.join(clean_ingredient)
    return cleaned_list

    
def clean_serving(words):
    words_list = words.split('\n')
    return words_list[0]

def extract_alcohol(ingredients):
    matches = []
    alcohol_ingredients = []
    for ingredient in ingredients: 
        for i,item in enumerate(alcohol):
            index = ingredient.lower().find(item.lower())
            if index != -1:
                matches.append((i,len(item)))
        biggest_index = 0
        for i,tup in enumerate(matches):
            if tup[0] > biggest_index:
                biggest_index = i
        try:
            #print(word[word_i],' contains ' ,alcohol[matches[biggest_index][1]])
            alcohol_ingredients.append(alcohol[matches[biggest_index][0]])
        except:
            pass
            #print(ingredients[word_i],' contains no alcohol' )

        matches = []
    return "|".join(alcohol_ingredients)

def extract_non_alcohol(ingredients): #NYI
    matches = []
    alcohol_ingredients = []
    for ingredient in ingredients: 
        for i,item in enumerate(alcohol):
            index = ingredient.lower().find(item.lower())
            if index == -1:
                alcohol_ingredients.append(ingredient)

        matches = []
    return "|".join(alcohol_ingredients)

# %%
df['ingredients_clean'] = df['ingredients'].apply(extract_words)
df['serving_suggestion_clean'] = df['serving_suggestion'].apply(clean_serving)
df['alcohol'] = df['ingredients_clean'].apply(extract_alcohol)

# %%
df
# Out:
#                                 name  \
# 0                     Abacaxi Ricaço
# 1                              Abbey
# 2                    A.B.C. Cocktail
# 3                  Absinthe Cocktail
# 4                    Absinthe Frappé
# ...                              ...
# 4739                  Greek Daiquiri
# 4740                         Cazador
# 4741                Spiced Alexander
# 4742  Sweet Liberty's Sherry Cobbler
# 4743                    Fair Harvard
#
#                                                 garnish  \
# 0     Cut a straw sized hole in the top of the pinea...
# 1                                     Orange zest twist
# 2          Lemon zest twist & Luxardo Maraschino cherry
# 3                                             Mint leaf
# 4                                   Mint sprigs bouquet
# ...                                                 ...
# 4739                                  Orange zest twist
# 4740     Lime zest twist or dehydrated lime wheel slice
# 4741                    Dust with freshly grated nutmeg
# 4742             Fresh raspberries & mint sprig bouquet
# 4743                                   Lemon zest twist
#
#                                      serving_suggestion  \
# 0             Serve in a Pineapple shell (frozen) glass
# 1                                Serve in a Coupe glass
# 2                          Serve in a Nick & Nora glass
# 3                                Serve in a Coupe glass
# 4                       Serve in an Old-fashioned glass
# ...                                                 ...
# 4739  Serve in a Coupe glass\nPhotographed in a Retr...
# 4740                             Serve in a Coupe glass
# 4741  Serve in a Coupe glass\nPhotographed in an UB ...
# 4742                              Serve in a Wine glass
# 4743  Serve in a Coupe glass\nPhotographed in an UB ...
#
#                                             ingredients  \
# 0     ['1 whole Pineapple (fresh)', '3 shot Havana C...
# 1     ['1 1⁄2 shot Rutte Dry Gin', '3⁄4 shot Lillet ...
# 2     ['7 fresh Mint leaves', '1 shot Tawny port', '...
# 3     ['1 shot La Fée Parisienne absinthe', '2 1⁄2 s...
# 4     ['1 shot La Fée Parisienne absinthe', '1⁄3 sho...
# ...                                                 ...
# 4739  ['1 2⁄3 shot O/Purist Tsipouro', '2⁄3 shot Lim...
# 4740  ['2 shot Bacardi 8 year old rum', '2⁄3 shot Li...
# 4741  ['1 1⁄2 shot Black Tears cacao & coffee spiced...
# 4742  ['2 1⁄2 shot Fino sherry', '1 shot Pink grapef...
# 4743  ['2 shot BarSol Mosto Verde Italia Pisco', '1 ...
#
#                                                   steps  review_count  \
# 0     Cut the top off a small pineapple and carefull...             4
# 1     SHAKE all ingredients with ice and fine strain...            11
# 2     TEAR mint and place in shaker. Add other ingre...             5
# 3     SHAKE all ingredients with ice and fine strain...             5
# 4     SHAKE all ingredients with ice and fine strain...             1
# ...                                                 ...           ...
# 4739  SHAKE all ingredients with ice and fine strain...             0
# 4740  SHAKE all ingredients with ice and fine strain...             5
# 4741  SHAKE all ingredients with ice and fine strain...             1
# 4742  SHAKE all ingredients with ice and strain into...            13
# 4743  STIR all ingredients with ice and strain into ...            15
#
#                                                     url   website  \
# 0     https://www.diffordsguide.com/cocktails/recipe...  diffords
# 1     https://www.diffordsguide.com/cocktails/recipe...  diffords
# 2     https://www.diffordsguide.com/cocktails/recipe...  diffords
# 3     https://www.diffordsguide.com/cocktails/recipe...  diffords
# 4     https://www.diffordsguide.com/cocktails/recipe...  diffords
# ...                                                 ...       ...
# 4739  https://www.diffordsguide.com/cocktails/recipe...  diffords
# 4740  https://www.diffordsguide.com/cocktails/recipe...  diffords
# 4741  https://www.diffordsguide.com/cocktails/recipe...  diffords
# 4742  https://www.diffordsguide.com/cocktails/recipe...  diffords
# 4743  https://www.diffordsguide.com/cocktails/recipe...  diffords
#
#                                               image_url  \
# 0     https://cdn.diffords.com/contrib/stock-images/...
# 1     https://cdn.diffords.com/contrib/stock-images/...
# 2     https://cdn.diffords.com/contrib/stock-images/...
# 3     https://cdn.diffords.com/contrib/stock-images/...
# 4     https://cdn.diffords.com/contrib/stock-images/...
# ...                                                 ...
# 4739  https://cdn.diffords.com/contrib/stock-images/...
# 4740  https://cdn.diffords.com/contrib/stock-images/...
# 4741  https://cdn.diffords.com/contrib/stock-images/...
# 4742  https://cdn.diffords.com/contrib/stock-images/...
# 4743  https://cdn.diffords.com/contrib/stock-images/...
#
#                                       ingredients_clean  \
# 0     [whole Pineapple, Havana Club Year Old rum, Li...
# 1     [Rutte Dry Gin, Lillet Blanc, Orange juice, An...
# 2     [Mint leaves, Tawny port, Rémy Martin Cognac, ...
# 3     [La Fée Parisienne absinthe, Chilled water, Su...
# 4     [La Fée Parisienne absinthe, Anisette liqueur,...
# ...                                                 ...
# 4739  [O Purist Tsipouro, Lime juice, Lemon juice, S...
# 4740  [Bacardi year old rum, Lime juice, Maple syrup...
# 4741  [Black Tears cacao coffee spiced rum, Dutch Ca...
# 4742  [Fino sherry, Pink grapefruit juice, St Germai...
# 4743  [BarSol Mosto Verde Italia Pisco, Martini Bian...
#
#                        serving_suggestion_clean                     alcohol
# 0     Serve in a Pineapple shell (frozen) glass                         rum
# 1                        Serve in a Coupe glass        gin|Aromatic Bitters
# 2                  Serve in a Nick & Nora glass   Cognac|Maraschino liqueur
# 3                        Serve in a Coupe glass                    absinthe
# 4               Serve in an Old-fashioned glass                    absinthe
# ...                                         ...                         ...
# 4739                     Serve in a Coupe glass              Orange Bitters
# 4740                     Serve in a Coupe glass                rum|absinthe
# 4741                     Serve in a Coupe glass                         rum
# 4742                      Serve in a Wine glass  sherry|elderflower liqueur
# 4743                     Serve in a Coupe glass     vermouth|Orange Bitters
#
# [4744 rows x 12 columns]

# %%
df.drop_duplicates().to_csv('./difford_1_5000_processed.csv', index=False)
df.drop_duplicates().to_parquet('./difford_1_5000_processed.parquet')

# %%
ingredient_dict = {}
ingredient_series = df['ingredients_clean']
for ingredients in ingredient_series:
    for ingredient in ingredients:
        if ingredient in list(ingredient_dict.keys()):
            ingredient_dict[ingredient] += 1
        else:
            ingredient_dict[ingredient] = 1

# %%
pd.set_option('max_rows', 100)
pd.DataFrame([ingredient_dict]).transpose().sort_values(0).tail(100)
alcohol = ['vodka', 
           'gin',
           'whiskey',
           'rum',
           'brandy liqueur',
           'Gentian liqueur',
           'soda water', 
           'Ginger liqueur',
           'amaretto', 
           'Calvados', 
           'bitters',
           'Chartreuse liqueur',
           'Coffee Liqueur',
           'bitter liqueur',
           'elderflower liqueur',
           'Maraschino liqueur',
           'absinthe',
           'tequila',
           'Orange Bitters',
           'vermouth',
           'Cognac',
           'Aromatic Bitters',
           'Hazelnut liqueur',
           'Vanilia vodka',
           'Chocolate bitters',
           'sherry',
           'sparkling wine',
           'Sauvignon blanc wine',
           'wine',
           'southern liqueur',
           'Apple Schnapps liqueur',
           'Coconut rum liqueur',
           'Limoncello',
           'peach schnapps',
           'Green melon liqueur',
           'aperitivo',
           'Drambuie liqueur',
           'port',
           'Chocolate bitters',
           'mezcal',
           'Noir de Bourgogne',
           'Banane du Brésil liqueur',
           'Falernum liqueur',
           'Irish cream liqueur',
           'Chartreuse liqueur',
           'Champagne',
           'Straight rye whiskey',
           'Gentian liqueur',
           'Framboise de Ronce'
           'Chartreuse',
           'cognac orange liqueur',
           'Dry vermouth',
           'sweet vermouth'
